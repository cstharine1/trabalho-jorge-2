# %% [markdown]
# ##Rede social
#
# uma rede social feita em python, usando o supabase (postgrees)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#estamos "abrindo o terminal" e baixando a lib
# !pip install supabase

# %%
# importando bibloteca
from supabase import create_client, Client


supabase: Client = create_client('https://vmkjqencbwuoeojznyfm.supabase.co', 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InZta2pxZW5jYnd1b2VvanpueWZtIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MjM4MTA4NTIsImV4cCI6MjAzOTM4Njg1Mn0.9QkadM6NEQjvUNbXI39VB_fq7_SgFLEhL_YBGpsMZUM')

# %%
#pegando todos os dados da tabela bento_alunos
response = supabase.table("aluno_posts").select("*, bento_alunos(user_name)").execute()

print((response.data[0]))
# Out:
# {'id': '5017adbd-9c32-42c2-9800-5f736b58277d', 'content': 'aaaaaaaaa', 'posted_at': '2001-09-11T12:33:31', 'bento_alunos_id': '17973102-e360-46ff-b863-e452ca319f2b', 'bento_alunos': {'user_name': 'antonio'}}

# %%
print((response.data))
# Out:
# [{'id': '5017adbd-9c32-42c2-9800-5f736b58277d', 'content': 'aaaaaaaaa', 'posted_at': '2001-09-11T12:33:31', 'bento_alunos_id': '17973102-e360-46ff-b863-e452ca319f2b', 'bento_alunos': {'user_name': 'antonio'}}, {'id': '8be56891-3d16-4582-8ec4-611c7e304cc5', 'content': 'bbbbbbbbb', 'posted_at': '2024-08-23T09:29:39', 'bento_alunos_id': '17973102-e360-46ff-b863-e452ca319f2b', 'bento_alunos': {'user_name': 'antonio'}}, {'id': '922053ef-1e04-4cc1-920d-98af74334269', 'content': 'oi, eu sou o guilherme', 'posted_at': '2024-10-09T19:46:47.902349', 'bento_alunos_id': None, 'bento_alunos': None}, {'id': 'ddc929d6-fce8-473c-997e-bed82908a89e', 'content': 'oi', 'posted_at': '2024-10-10T12:55:15.090117', 'bento_alunos_id': None, 'bento_alunos': None}]

# %%
def main():
  print("pagina inicial")

  print("1 - fazer um post")
  print("2 - ver os posts")
  print("3 - sair")
  option = int(input("escolha uma opção: "))

  if option == 1:
    content = input("digite o seu post: ")
    response = supabase.table("aluno_posts").insert({"content": content, "bento_aluno_id": user }).execute()
    return
  if option == 2:
    response = supabase.table("aluno_posts").select(" bento_alunos(user_name) , content , posted_at").execute()
    print(response.data)
    print("1 - voltar")
    print("2 - sair")
    option = int(input("escolha uma opção: "))
    if option == 1:
      main()
    if option == 2:
      print("saindo...")
    else:
      print("opção inválida")
      main()
    return
  if option == 3:
    print("sair")
    return
  else:
    print("opção inválida")

# %%
def cadastro():

  user_name = input("nome de usuário: ")
  password = input("senha: ")
  nome = input("nome: ")


  response = supabase.table("bento_alunos").insert({ "user_name": user_name, "password": password, "name": nome, }).execute()
  main()
  return

# %%
def login():
  user_name = input("nome de usuário: ")
  password = input("senha: ")
  global user
  user = supabase.table("bento_alunos").select("*").eq("user_name", user_name).eq("password", password).execute()

  if len(user.data) > 0:
    print("logado com sucesso")
    print("1 - entrar")
    print("2 - sair")
    option = int(input("escolha uma opção: "))

  if len(user.data) == 0:
    print("usuário ou senha incorretos")
    login()
    return


  if option == 1:
    main()
    return
  if option == 2:
    showMenu()
    return

  else:
    print("usuário ou senha incorretos")
    login()
  return

# %%
import sys
def showMenu():
  print("bentwitter")
  print("1 - cadastrar")
  print("2 - login")
  print("3 - sair")
  option = int(input("escolha uma opção: "))

  if option == 1:
    cadastro()
    return
  if option == 2:
    login()
    return
  if option == 3:
    print("sair")
    sys.exit()
  else:
    print("opção inválida")
    showMenu()
  return

# %%
showMenu()
# Out:
# bentwitter
# 1 - cadastrar
# 2 - login
# 3 - sair
# escolha uma opção: 1
# nome de usuário: sjbsdjfs
# senha: 12512512
# nome: ujgbsous
# pagina inicial
# 1 - fazer um post
# 2 - ver os posts
# 3 - sair
# escolha uma opção: 3
# sair
